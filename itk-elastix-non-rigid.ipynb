# %% [markdown]
# ### Elastix Image Registration

# %%
import itk
from itkwidgets import view
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load the images

# %%
# Load the images
fixed_image = itk.imread('C:/Users/BazB1/Desktop/Work/in2research/Data/CAMUS_public/database_nifti/patient0001/patient0001_2CH_ED.nii.gz')
moving_image = itk.imread('C:/Users/BazB1/Desktop/Work/in2research/Data/CAMUS_public/database_nifti/patient0001/patient0001_2CH_ES.nii.gz')

# %% [markdown]
# #### Register the moving image to the fixed image using Elastix registration.

# %%
# Obtain the registered image and the transform parameters
registered_image, params = itk.elastix_registration_method(fixed_image, moving_image)

# %%
registered_image
# Out:
# <itk.itkImagePython.itkImageF2; proxy of <Swig Object of type 'itkImageF2 *' at 0x00000243E1CD9080> >

# %%
params
# Out:
# <itk.elxParameterObjectPython.elastixParameterObject; proxy of <Swig Object of type 'elastixParameterObject *' at 0x00000243E1CD8FF0> >

# %%
print(params)
# Out:
# ParameterObject (0000024397DFA470)
#   RTTI typeinfo:   class elastix::ParameterObject
#   Reference Count: 1
#   Modified Time: 117901
#   Debug: Off
#   Object Name:
#   Observers:
#     none
# ParameterMap 0:
#   (CompressResultImage "false")
#   (DefaultPixelValue 0)
#   (Direction 1 0 0 1)
#   (FinalBSplineInterpolationOrder 3)
#   (FixedImageDimension 2)
#   (FixedInternalImagePixelType "float")
#   (HowToCombineTransforms "Compose")
#   (Index 0 0)
#   (InitialTransformParametersFileName "NoInitialTransform")
#   (MovingImageDimension 2)
#   (MovingInternalImagePixelType "float")
#   (NumberOfParameters 2)
#   (Origin 0 0)
#   (ResampleInterpolator "FinalBSplineInterpolator")
#   (Resampler "DefaultResampler")
#   (ResultImageFormat "nii")
#   (ResultImagePixelType "float")
#   (Size 549 389)
#   (Spacing 0.308 0.308)
#   (Transform "TranslationTransform")
#   (TransformParameters -0.00492996 0.00503954)
#   (UseDirectionCosines "true")
# ParameterMap 1:
#   (CenterOfRotationPoint 84.3871 59.757)
#   (CompressResultImage "false")
#   (DefaultPixelValue 0)
#   (Direction 1 0 0 1)
#   (FinalBSplineInterpolationOrder 3)
#   (FixedImageDimension 2)
#   (FixedInternalImagePixelType "float")
#   (HowToCombineTransforms "Compose")
#   (Index 0 0)
#   (InitialTransformParametersFileName "output_path_not_set\TransformParameters.0.txt")
#   (MovingImageDimension 2)
#   (MovingInternalImagePixelType "float")
#   (NumberOfParameters 6)
#   (Origin 0 0)
#   (ResampleInterpolator "FinalBSplineInterpolator")
#   (Resampler "DefaultResampler")
#   (ResultImageFormat "nii")
#   (ResultImagePixelType "float")
#   (Size 549 389)
#   (Spacing 0.308 0.308)
#   (Transform "AffineTransform")
#   (TransformParameters 0.998699 -0.000323675 -0.000225102 0.998765 -0.00351069 -0.00602353)
#   (UseDirectionCosines "true")
# ParameterMap 2:
#   (BSplineTransformSplineOrder 3)
#   (CompressResultImage "false")
#   (DefaultPixelValue 0)
#   (Direction 1 0 0 1)
#   (FinalBSplineInterpolationOrder 3)
#   (FixedImageDimension 2)
#   (FixedInternalImagePixelType "float")
#   (GridDirection 1 0 0 1)
#   (GridIndex 0 0)
#   (GridOrigin -10.5146 -10.1848)
#   (GridSize 20 15)
#   (GridSpacing 9.98928 9.99083)
#   (HowToCombineTransforms "Compose")
#   (Index 0 0)
#   (InitialTransformParametersFileName "output_path_not_set\TransformParameters.1.txt")
#   (MovingImageDimension 2)
#   (MovingInternalImagePixelType "float")
#   (NumberOfParameters 600)
#   (Origin 0 0)
#   (ResampleInterpolator "FinalBSplineInterpolator")
#   (Resampler "DefaultResampler")
#   (ResultImageFormat "nii")
#   (ResultImagePixelType "float")
#   (Size 549 389)
#   (Spacing 0.308 0.308)
#   (Transform "BSplineTransform")
#   (TransformParameters -0.000917962 0.00224816 0.00688203 0.020127 0.0362565 0.051148 0.0807438 0.209308 0.406574 0.349884 -0.019583 -0.403041 -0.405128 -0.317605 -0.210744 -0.108171 -0.0496535 -0.0194398 -0.00390704 0.00181251 0.00322695 0.0360635 0.0524503 0.0505123 0.0435094 0.0637982 0.0415944 -0.0040067 -0.00994869 0.511532 -0.234237 -0.837963 -0.941172 -0.910367 -0.702514 -0.45544 -0.253638 -0.122163 -0.0562092 0.00268329 0.00986559 0.0942022 0.125988 0.093628 0.0315361 0.0239182 -0.0856862 -0.373404 -1.28701 -0.345961 0.0115002 -0.243182 -0.961096 -1.06158 -0.854311 -0.588301 -0.354017 -0.192112 -0.102234 -0.000811139 0.0249695 0.256963 0.333015 0.244074 0.0522751 0.00959189 -0.279401 0.0848744 1.44197 0.738243 -0.0904335 -0.182277 -1.06786 -1.47735 -1.20142 -0.798553 -0.51895 -0.332492 -0.199498 -0.0101154 0.0567392 0.472108 0.595819 0.423852 0.0279487 -0.158461 -0.645883 0.86949 7.12613 4.81178 -1.05254 -2.43151 -1.9383 -1.59409 -1.28128 -0.987212 -0.714278 -0.495323 -0.323831 -0.0301258 0.116741 0.676397 0.809387 0.588099 0.0394687 -0.30082 -0.282875 2.33012 8.53163 6.19923 -0.0295498 -5.15529 -3.97914 -1.67879 -1.28876 -1.25239 -0.857673 -0.620356 -0.440119 -0.0635673 0.210623 0.79137 0.847417 0.58847 0.453973 -0.160163 -1.05959 0.703849 7.57352 7.68255 1.96437 -5.08551 -6.50882 -2.62328 -0.760795 -1.27013 -0.830024 -0.633943 -0.491365 -0.104798 0.35243 0.813521 0.727445 0.123072 0.478678 0.637767 -0.046579 1.24458 6.05896 6.42229 1.32957 -5.03676 -8.51307 -5.35463 -1.68189 -1.38241 -1.
#   (UseCyclicTransform "false")
#   (UseDirectionCosines "true")

# %%
# Convert ITK images to numpy arrays
fixed_image_np = itk.array_from_image(fixed_image)
registered_image_np = itk.array_from_image(registered_image)
moving_image_np = itk.array_from_image(moving_image)

# %% [markdown]
# #### Plot the registered image alongside the fixed and moving images.

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.imshow(fixed_image_np, cmap='gray')
plt.title('Fixed image (ED)')
plt.subplot(1,3,2)
plt.imshow(moving_image_np, cmap='gray')
plt.title('Moving image (ES)')
plt.subplot(1,3,3)
plt.imshow(registered_image_np, cmap='gray')
plt.title('Registered image')
# Out:
# Text(0.5, 1.0, 'Registered image')

# %% [markdown]
# #### Interactively explore the registered image using the `itkwidgets` viewer.

# %%
view(fixed_image)
# Out:
#                 <img id="screenshot_imjoy_window_d71e36ed-b5cb-4e73-b88f-8fabf75fb1a2" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_d71e36ed-b5cb-4e73-b88f-8fabf75fb1a2");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_d71e36ed-b5cb-4e73-b88f-8fabf75fb1a2");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="585a8046-a793-48ba-b831-aae559f988e6"></div>

# %%
view(moving_image)
# Out:
#                 <img id="screenshot_imjoy_window_940f2352-7b8e-42a4-b199-ba6d6876eb36" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_940f2352-7b8e-42a4-b199-ba6d6876eb36");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_940f2352-7b8e-42a4-b199-ba6d6876eb36");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="61750d9d-0af2-46dd-af9f-ee5724760d1b"></div>

# %%
# display the result
view(registered_image)
# Out:
#                 <img id="screenshot_imjoy_window_65e14fff-0b23-486d-af81-a5df630a1755" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_65e14fff-0b23-486d-af81-a5df630a1755");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_65e14fff-0b23-486d-af81-a5df630a1755");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="35258e47-30dc-4697-aca4-e99688267c35"></div>

# %% [markdown]
# #### Compute similarity metrics between the moving and registered images.

# %%
from skimage.metrics import structural_similarity

# Compute the MSE between the registered image and the moving image
mse = np.mean((registered_image_np - moving_image_np)**2)
print('MSE: ', mse)

# Compute the PSNR between the registered image and the moving image
psnr = 10 * np.log10(255**2 / mse)
print('PSNR: ', psnr)

# Compute the NRMSE between the registered image and the moving image
nrmse = np.sqrt(mse)/np.std(moving_image_np)
print('NRMSE: ', nrmse)

# Compute the normalized cross-correlation between the registered image and the moving image
ncc = np.mean((registered_image_np - np.mean(registered_image_np))*(moving_image_np - np.mean(moving_image_np)))/(np.std(registered_image_np)*np.std(moving_image_np))
print('NCC: ', ncc)

# Compute the SSIM between the registered image and the moving image
ssim = structural_similarity(registered_image_np, moving_image_np)
print('SSIM: ', ssim)
# Out:
# MSE:  687.0294
# PSNR:  19.76105026702012
# NRMSE:  0.27845562
# NCC:  0.9611991
# SSIM:  0.5135145128200753
